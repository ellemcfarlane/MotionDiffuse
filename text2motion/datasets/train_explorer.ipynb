# %%
import os
from collections import defaultdict
from os.path import join as pjoin
import numpy as np

from motionx_explorer import load_label_from_file, motion_arr_to_dict
from statistics_writer import get_train_seqs, calc_mean_stddev_pose, names_to_arrays

# %%
data_dir = "../data/GRAB/"
emotions_dir = pjoin(data_dir, "face_texts")
motion_label_dir = pjoin(data_dir, "texts")
print(f"data dir: {data_dir}")
print(f"emotions_dir: {emotions_dir}")
print(f"motion_label_dir: {motion_label_dir}")
print(f"cwd {os.getcwd()}")
# Out:
# data dir: ../data/GRAB/
# emotions_dir: ../data/GRAB/face_texts
# motion_label_dir: ../data/GRAB/texts
# cwd /work3/s222376/MotionDiffuse2/text2motion/datasets

# %%
def label_code(full_label):
    # take first 3 letters of label
    return full_label[:3]

# %%
def get_seq_type(file_name):
    seq_type_path = pjoin(motion_label_dir, f"{file_name}.txt")
    with open(seq_type_path, 'r') as f:
        seq_type = f.readline().strip()
    return seq_type

# %%
train_names = get_train_seqs(pjoin(data_dir, "train.txt"))
seq_type_to_emotions = defaultdict(set)
emotions_count = defaultdict(int)
seq_type_count = defaultdict(int)
obj_count = defaultdict(int)
code_to_label = {}
emotion_to_name = defaultdict(list)
for name in train_names:
    seq_type = get_seq_type(name)
    emotion = load_label_from_file(pjoin(emotions_dir, f"{name}.txt"))
    object_ = seq_type.split(" ")[0]
    seq_type_to_emotions[seq_type].add(emotion)
    emo_code = label_code(emotion)
    emotions_count[emo_code] += 1
    seq_type_count[seq_type] += 1
    obj_code = label_code(object_)
    obj_count[label_code(object_)] += 1
    code_to_label[emo_code] = emotion
    code_to_label[obj_code] = object_
    emotion_to_name[emo_code].append(name)

# %%
n_types = len(seq_type_to_emotions.keys())
# print results, sorted alphabetically by seq_type
sorted_seq_types = sorted(seq_type_to_emotions.keys())
for seq_type in sorted_seq_types:
    emotions = seq_type_to_emotions[seq_type]
    print(f"{seq_type}: {emotions}")
# Out:
# airplane fly: {'fear', 'anger', 'happiness', 'thinking', 'neutral'}
# airplane lift: {'surprise', 'bothered', 'fear', 'unsure'}
# airplane lift Retake: {'thinking'}
# airplane offhand: {'anger', 'thinking'}
# airplane pass: {'fear', 'disgust', 'sadness', 'happiness', 'anger'}
# alarmclock lift: {'sadness', 'neutral', 'thinking', 'fear'}
# alarmclock lift Retake: {'intrest'}
# alarmclock offhand: {'neutral', 'disgust'}
# alarmclock pass: {'neutral', 'unsure', 'thinking', 'fear'}
# alarmclock see: {'unsure', 'anger', 'happiness', 'sadness', 'intrest', 'bothered'}
# apple eat: {'neutral', 'anger', 'fear', 'unsure'}
# apple lift: {'unsure', 'happiness', 'bothered', 'thinking', 'concentrating'}
# apple offhand: {'sadness'}
# apple offhand Retake: {'bothered'}
# apple pass: {'unsure', 'fear', 'sadness', 'bothered', 'surprise', 'neutral'}
# banana eat: {'concentrating', 'happiness', 'unsure', 'thinking'}
# banana lift: {'happiness', 'bothered', 'disgust'}
# banana pass: {'unsure', 'disgust', 'sadness', 'contempt', 'neutral'}
# banana peel: {'unsure', 'disgust', 'sadness', 'anger', 'thinking', 'contempt', 'neutral'}
# binoculars lift: {'anger', 'boredom', 'disgust'}
# binoculars offhand: {'anger'}
# binoculars pass: {'fear', 'disgust', 'sadness', 'happiness', 'bothered'}
# binoculars see: {'happiness', 'bothered', 'neutral', 'disgust'}
# bowl drink: {'unsure', 'fear', 'disgust', 'happiness', 'thinking', 'concentrating', 'neutral'}
# bowl drink Retake: {'boredom', 'disgust'}
# bowl lift: {'disgust', 'sadness', 'happiness', 'thinking', 'neutral'}
# bowl offhand: {'thinking'}
# bowl pass: {'sadness', 'happiness', 'surprise', 'disgust'}
# camera browse: {'anger', 'happiness', 'fear', 'disgust'}
# camera lift: {'happiness', 'thinking'}
# camera offhand: {'boredom', 'neutral'}
# camera pass: {'unsure', 'disgust', 'sadness', 'happiness', 'neutral'}
# camera takepicture: {'unsure', 'disgust', 'anger', 'happiness', 'boredom', 'sadness', 'thinking', 'neutral'}
# camera takepicture Retake: {'sadness'}
# cubelarge inspect: {'unsure', 'disgust', 'sadness', 'thinking', 'neutral'}
# cubelarge lift: {'sadness', 'happiness', 'boredom', 'intrest', 'bothered', 'neutral'}
# cubelarge offhand: {'happiness', 'neutral'}
# cubelarge pass: {'sadness', 'happiness', 'anger', 'boredom', 'neutral'}
# cubemedium inspect: {'anger', 'happiness', 'unsure', 'sadness'}
# cubemedium lift: {'happiness', 'bothered', 'concentrating', 'surprise', 'neutral'}
# cubemedium offhand: {'happiness', 'disgust'}
# cubemedium pass: {'unsure', 'anger', 'happiness', 'boredom', 'sadness', 'thinking', 'concentrating', 'neutral'}
# cubesmall inspect: {'unsure', 'sadness', 'happiness', 'boredom', 'bothered', 'neutral'}
# cubesmall lift: {'unsure', 'sadness', 'bothered', 'surprise', 'neutral'}
# cubesmall offhand: {'anger', 'happiness'}
# cubesmall pass: {'sadness', 'happiness', 'anger', 'concentrating', 'surprise'}
# cup drink: {'unsure', 'disgust', 'sadness', 'happiness', 'bothered', 'intrest', 'concentrating', 'neutral'}
# cup lift: {'concentrating', 'boredom', 'unsure', 'sadness'}
# cup offhand: {'bothered', 'neutral'}
# cup pass: {'unsure', 'disgust', 'sadness', 'anger', 'boredom', 'neutral'}
# cup pour: {'happiness', 'neutral', 'unsure'}
# cylinderlarge inspect: {'unsure', 'disgust', 'sadness', 'happiness', 'boredom', 'anger', 'concentrating'}
# cylinderlarge lift: {'unsure', 'anger', 'sadness', 'bothered', 'happiness', 'neutral'}
# cylinderlarge lift Retake: {'sadness'}
# cylinderlarge offhand: {'sadness', 'anger'}
# cylinderlarge pass: {'unsure', 'sadness', 'happiness', 'boredom', 'intrest'}
# cylindermedium inspect: {'fear', 'disgust', 'sadness', 'happiness', 'bothered'}
# cylindermedium lift: {'anger', 'happiness', 'boredom', 'surprise', 'neutral'}
# cylindermedium offhand: {'bothered'}
# cylindermedium pass: {'unsure', 'fear', 'disgust', 'anger', 'happiness', 'sadness', 'neutral'}
# cylindersmall inspect: {'unsure', 'disgust', 'anger', 'sadness', 'happiness', 'thinking'}
# cylindersmall lift: {'neutral', 'thinking', 'fear'}
# cylindersmall offhand: {'thinking'}
# cylindersmall pass: {'unsure', 'fear', 'sadness', 'concentrating', 'neutral'}
# doorknob lift: {'happiness', 'bothered', 'neutral'}
# doorknob use: {'unsure', 'sadnes', 'happiness', 'intrest', 'thinking', 'concentrating', 'neutral'}
# doorknob use fun: {'disgust'}
# duck inspect: {'disgust', 'anger', 'sadness', 'intrest', 'neutral'}
# duck lift: {'anger', 'neutral', 'unsure'}
# duck pass: {'anger', 'happiness', 'bothered', 'intrest', 'neutral'}
# elephant inspect: {'unsure', 'disgust', 'sadness', 'happiness', 'surprise', 'neutral'}
# elephant lift: {'boredom', 'neutral', 'unsure', 'thinking'}
# elephant offhand: {'boredom'}
# elephant pass: {'disgust', 'anger', 'happiness', 'thinking', 'contempt', 'surprise', 'neutral'}
# eyeglasses clean: {'sadness', 'neutral', 'unsure', 'disgust'}
# eyeglasses lift: {'concentrating', 'bothered', 'neutral', 'anger'}
# eyeglasses offhand: {'happiness', 'disgust'}
# eyeglasses pass: {'concentrating', 'bothered', 'neutral', 'unsure'}
# eyeglasses wear: {'disgust', 'sadness', 'boredom', 'bothered', 'neutral'}
# flashlight lift: {'happiness', 'intrest', 'disgust'}
# flashlight offhand: {'sadness', 'bothered'}
# flashlight on: {'disgust', 'sadness', 'anger', 'thinking', 'concentrating', 'neutral'}
# flashlight pass: {'unsure', 'sadness', 'happiness', 'bothered', 'surprise'}
# flute lift: {'neutral', 'thinking'}
# flute offhand: {'bothered', 'fear'}
# flute pass: {'fear', 'sadness', 'anger', 'bothered', 'neutral'}
# flute play: {'fear', 'sadness', 'happiness', 'bothered', 'thinking', 'concentrating'}
# fryingpan cook: {'unsure', 'disgust', 'sadness', 'happiness', 'boredom', 'intrest', 'neutral'}
# fryingpan lift: {'thinking', 'disgust'}
# fryingpan offhand: {'disgust'}
# fryingpan pass: {'sadness', 'happiness', 'anger', 'thinking'}
# gamecontroller lift: {'sadness', 'intrest', 'neutral'}
# gamecontroller offhand: {'unsure'}
# gamecontroller pass: {'unsure', 'fear', 'disgust', 'sadness', 'happiness', 'neutral'}
# gamecontroller play: {'disgust', 'anger', 'happiness', 'intrest', 'thinking', 'surprise', 'neutral'}
# hammer lift: {'anger', 'sadness', 'bothered', 'boredom'}
# hammer pass: {'happiness', 'surprise', 'neutral', 'bothered'}
# hammer use: {'unsure', 'disgust', 'anger', 'happiness', 'sadness', 'intrest', 'thinking', 'concentrating', 'surprise', 'neutral'}
# hand inspect: {'sadness', 'happiness', 'bothered', 'surprise', 'neutral'}
# hand lift: {'happiness', 'bothered', 'neutral', 'boredom'}
# hand pass: {'unsure', 'sadness', 'boredom', 'surprise', 'neutral'}
# hand shake: {'anger', 'bothered'}
# headphones lift: {'sadness', 'boredom', 'unsure', 'disgust'}
# headphones pass: {'unsure', 'disgust', 'sadness', 'happiness', 'thinking', 'surprise', 'neutral'}
# headphones use: {'fear', 'sadness', 'happiness', 'thinking', 'concentrating', 'neutral'}
# knife chop: {'concentrating', 'bothered'}
# knife lift: {'fear', 'neutral'}
# knife pass: {'boredom', 'neutral'}
# knife peel: {'neutral', 'unsure'}
# lightbulb pass: {'bothered', 'neutral', 'fear'}
# lightbulb screw: {'happiness', 'fear'}
# mouse lift: {'unsure', 'anger', 'bothered', 'intrest', 'thinking', 'neutral'}
# mouse pass: {'unsure', 'anger', 'happiness', 'intrest', 'concentrating', 'neutral'}
# mouse use: {'unsure', 'fear', 'disgust', 'sadness', 'bothered', 'thinking'}
# mug drink: {'unsure', 'fear', 'anger', 'happiness', 'sadness', 'contempt', 'thinking', 'concentrating', 'neutral'}
# mug lift: {'sadness', 'boredom', 'neutral', 'thinking'}
# mug offhand: {'bothered', 'fear', 'surprise'}
# mug pass: {'anger', 'bothered', 'thinking'}
# mug toast: {'concentrating', 'happiness', 'unsure', 'disgust'}
# phone call: {'sadness', 'happiness', 'thinking', 'surprise', 'neutral'}
# phone lift: {'disgust', 'happiness', 'boredom', 'intrest', 'neutral'}
# phone offhand: {'surprise', 'disgust'}
# phone pass: {'fear', 'disgust', 'anger', 'sadness', 'happiness', 'concentrating'}
# piggybank lift: {'sadness', 'happiness', 'bothered', 'disgust'}
# piggybank lift Retake: {'neutral', 'thinking'}
# piggybank offhand: {'unsure'}
# piggybank pass: {'fear', 'happiness', 'bothered', 'thinking', 'concentrating', 'neutral'}
# piggybank pass Retake: {'thinking'}
# piggybank use: {'unsure', 'contepmt', 'anger', 'happiness', 'boredom', 'neutral'}
# pyramidlarge inspect: {'unsure', 'disgust', 'anger', 'happiness', 'boredom', 'thinking'}
# pyramidlarge lift: {'fear', 'unsure', 'disgust'}
# pyramidlarge offhand: {'happiness', 'intrest'}
# pyramidlarge pass: {'sadness', 'happiness', 'bothered', 'concentrating'}
# pyramidlarge pass Retake: {'concentrating'}
# pyramidmedium inspect: {'unsure', 'fear', 'disgust', 'anger', 'happiness', 'thinking', 'neutral'}
# pyramidmedium lift: {'neutral'}
# pyramidmedium lift Retake: {'happiness'}
# pyramidmedium offhand: {'boredom'}
# pyramidmedium pass: {'unsure', 'happiness', 'bothered', 'thinking', 'neutral'}
# pyramidsmall inspect: {'happiness', 'thinking'}
# pyramidsmall pass: {'sadness', 'neutral'}
# scissors offhand: {'thinking'}
# scissors pass: {'sadness', 'bothered', 'thinking', 'contempt'}
# scissors use: {'boredom', 'unsure', 'thinking'}
# spherelarge inspect: {'sadness', 'happiness', 'boredom', 'anger', 'thinking', 'concentrating', 'neutral'}
# spherelarge lift: {'unsure', 'anger', 'happiness', 'thinking', 'neutral'}
# spherelarge offhand: {'thinking'}
# spherelarge pass: {'sadness', 'neutral'}
# spheremedium inspect: {'anger', 'fear', 'unsure', 'sadness'}
# spheremedium lift: {'concentrating', 'neutral', 'unsure', 'sadness'}
# spheremedium offhand: {'unsure'}
# spheremedium pass: {'unsure', 'fear', 'disgust', 'bothered', 'neutral'}
# spheresmall inspect: {'disgust', 'happiness', 'bothered', 'boredom', 'surprise'}
# spheresmall lift: {'happiness', 'unsure', 'thinking'}
# spheresmall offhand: {'neutral'}
# spheresmall pass: {'disgust', 'sadness', 'intrest', 'thinking', 'concentrating'}
# stamp lift: {'unsure', 'fear', 'bothered', 'thinking', 'neutral'}
# stamp offhand: {'thinking'}
# stamp pass: {'sadness', 'happiness', 'surprise', 'anger'}
# stamp stamp: {'unsure', 'sadness', 'happiness', 'anger', 'boredom', 'neutral'}
# stanfordbunny inspect: {'unsure', 'disgust', 'sadness', 'happiness', 'boredom'}
# stanfordbunny lift: {'unsure', 'sadness', 'anger', 'thinking', 'surprise'}
# stanfordbunny offhand: {'thinking'}
# stanfordbunny pass: {'disgust', 'sadness', 'happiness', 'bothered', 'anger', 'thinking', 'neutral'}
# stapler lift: {'disgust', 'sadness', 'anger', 'thinking', 'neutral'}
# stapler offhand: {'unsure'}
# stapler offhand Retake: {'thinking'}
# stapler pass: {'unsure', 'disgust', 'sadness', 'happiness', 'bothered', 'thinking'}
# stapler staple: {'disgust', 'anger', 'happiness', 'boredom', 'intrest', 'thinking', 'contempt', 'concentrating', 'neutral'}
# teapot lift: {'happiness', 'fear'}
# teapot pass: {'unsure', 'fear', 'happiness', 'bothered', 'neutral'}
# teapot pour: {'unsure', 'disgust', 'sadness', 'happiness', 'thinking', 'neutral'}
# toothbrush brush: {'sadness', 'disgust'}
# toothbrush lift: {'disgust'}
# toothbrush pass: {'fear', 'happiness', 'bothered', 'thinking', 'surprise'}
# toothpaste lift: {'anger', 'happiness', 'neutral', 'disgust'}
# toothpaste pass: {'anger', 'boredom', 'neutral', 'unsure'}
# toothpaste squeeze: {'unsure', 'fear', 'sadness', 'thinking', 'concentrating', 'neutral'}
# toothpaste squeeze Retake: {'concentrating'}
# toruslarge inspect: {'anger', 'boredom', 'unsure', 'disgust'}
# toruslarge inspect Retake: {'unsure'}
# toruslarge lift: {'sadness', 'concentrating', 'unsure', 'boredom'}
# toruslarge pass: {'unsure', 'fear', 'sadness', 'concentrating', 'neutral'}
# torusmedium inspect: {'sadness', 'happiness', 'neutral', 'unsure'}
# torusmedium lift: {'bothered', 'neutral'}
# torusmedium offhand: {'unsure'}
# torusmedium pass: {'unsure', 'anger', 'happiness', 'bothered', 'thinking'}
# torussmall inspect: {'sadness', 'happiness', 'unsure'}
# torussmall lift: {'happiness', 'fear', 'neutral'}
# torussmall offhand: {'neutral'}
# torussmall pass: {'unsure', 'disgust', 'sadness', 'happiness', 'contempt', 'neutral'}
# train lift: {'sadness', 'neutral', 'unsure', 'thinking'}
# train pass: {'unsure', 'disgust', 'anger', 'happiness', 'boredom', 'neutral'}
# train play: {'disgust', 'anger', 'happiness', 'sadness', 'concentrating'}
# watch lift: {'sadness', 'surprise', 'anger'}
# watch offhand: {'disgust'}
# watch pass: {'unsure', 'sadness', 'happiness', 'thinking', 'neutral'}
# watch set: {'unsure', 'fear', 'sadness', 'boredom', 'concentrating', 'neutral'}
# waterbottle drink: {'disgust', 'sadness', 'happiness', 'intrest', 'thinking', 'concentrating'}
# waterbottle lift: {'concentrating', 'happiness', 'fear', 'unsure'}
# waterbottle open: {'anger', 'fear', 'neutral', 'thinking'}
# waterbottle open Retake: {'concentrating'}
# waterbottle pass: {'fear', 'sadness', 'happiness', 'anger', 'concentrating'}
# waterbottle pour: {'concentrating', 'unsure', 'thinking', 'disgust'}
# waterbottle shake: {'anger', 'sadness', 'boredom', 'bothered', 'concentrating'}
# wineglass drink: {'unsure', 'fear', 'disgust', 'sadness', 'happiness', 'boredom', 'anger', 'thinking', 'contempt', 'concentrating', 'neutral'}
# wineglass lift: {'sadness', 'fear', 'neutral', 'thinking'}
# wineglass offhand: {'anger'}
# wineglass pass: {'unsure', 'sadness', 'happiness', 'thinking', 'neutral'}
# wineglass toast: {'unsure', 'disgust', 'anger', 'happiness', 'thinking'}

# %%
sorted_emos = sorted(emotions_count.keys())
for emo in sorted_emos:
    print(f"{code_to_label[emo]}: {emotions_count[emo]}")
# Out:
# anger: 83
# boredom: 42
# bothered: 59
# concentrating: 59
# disgust: 83
# fear: 51
# happiness: 140
# intrest: 21
# neutral: 153
# sadness: 131
# surprise: 26
# thinking: 90
# unsure: 130

# %%
sorted_motions = sorted(seq_type_count.keys())
for motion in sorted_motions:
    print(f"{motion}: {seq_type_count[motion]}")
# Out:
# airplane fly: 7
# airplane lift: 5
# airplane lift Retake: 1
# airplane offhand: 2
# airplane pass: 6
# alarmclock lift: 7
# alarmclock lift Retake: 1
# alarmclock offhand: 2
# alarmclock pass: 4
# alarmclock see: 8
# apple eat: 7
# apple lift: 8
# apple offhand: 1
# apple offhand Retake: 1
# apple pass: 9
# banana eat: 6
# banana lift: 3
# banana pass: 6
# banana peel: 11
# binoculars lift: 4
# binoculars offhand: 1
# binoculars pass: 5
# binoculars see: 7
# bowl drink: 12
# bowl drink Retake: 2
# bowl lift: 5
# bowl offhand: 1
# bowl pass: 6
# camera browse: 7
# camera lift: 2
# camera offhand: 2
# camera pass: 9
# camera takepicture: 16
# camera takepicture Retake: 1
# cubelarge inspect: 7
# cubelarge lift: 6
# cubelarge offhand: 2
# cubelarge pass: 8
# cubemedium inspect: 7
# cubemedium lift: 7
# cubemedium offhand: 2
# cubemedium pass: 8
# cubesmall inspect: 7
# cubesmall lift: 6
# cubesmall offhand: 2
# cubesmall pass: 5
# cup drink: 12
# cup lift: 5
# cup offhand: 2
# cup pass: 8
# cup pour: 6
# cylinderlarge inspect: 10
# cylinderlarge lift: 8
# cylinderlarge lift Retake: 1
# cylinderlarge offhand: 2
# cylinderlarge pass: 6
# cylindermedium inspect: 7
# cylindermedium lift: 6
# cylindermedium offhand: 1
# cylindermedium pass: 8
# cylindersmall inspect: 7
# cylindersmall lift: 3
# cylindersmall offhand: 1
# cylindersmall pass: 6
# doorknob lift: 5
# doorknob use: 10
# doorknob use fun: 1
# duck inspect: 8
# duck lift: 5
# duck pass: 5
# elephant inspect: 7
# elephant lift: 5
# elephant offhand: 1
# elephant pass: 8
# eyeglasses clean: 5
# eyeglasses lift: 4
# eyeglasses offhand: 2
# eyeglasses pass: 5
# eyeglasses wear: 6
# flashlight lift: 3
# flashlight offhand: 2
# flashlight on: 10
# flashlight pass: 5
# flute lift: 2
# flute offhand: 2
# flute pass: 8
# flute play: 8
# fryingpan cook: 10
# fryingpan lift: 2
# fryingpan offhand: 1
# fryingpan pass: 4
# gamecontroller lift: 4
# gamecontroller offhand: 1
# gamecontroller pass: 6
# gamecontroller play: 9
# hammer lift: 4
# hammer pass: 5
# hammer use: 19
# hand inspect: 7
# hand lift: 5
# hand pass: 7
# hand shake: 2
# headphones lift: 4
# headphones pass: 7
# headphones use: 7
# knife chop: 2
# knife lift: 2
# knife pass: 3
# knife peel: 3
# lightbulb pass: 3
# lightbulb screw: 3
# mouse lift: 6
# mouse pass: 7
# mouse use: 9
# mug drink: 16
# mug lift: 5
# mug offhand: 3
# mug pass: 4
# mug toast: 5
# phone call: 7
# phone lift: 5
# phone offhand: 2
# phone pass: 6
# piggybank lift: 5
# piggybank lift Retake: 2
# piggybank offhand: 1
# piggybank pass: 8
# piggybank pass Retake: 1
# piggybank use: 7
# pyramidlarge inspect: 8
# pyramidlarge lift: 4
# pyramidlarge offhand: 2
# pyramidlarge pass: 5
# pyramidlarge pass Retake: 1
# pyramidmedium inspect: 8
# pyramidmedium lift: 1
# pyramidmedium lift Retake: 1
# pyramidmedium offhand: 1
# pyramidmedium pass: 9
# pyramidsmall inspect: 3
# pyramidsmall pass: 3
# scissors offhand: 1
# scissors pass: 4
# scissors use: 4
# spherelarge inspect: 8
# spherelarge lift: 6
# spherelarge offhand: 1
# spherelarge pass: 4
# spheremedium inspect: 6
# spheremedium lift: 6
# spheremedium offhand: 1
# spheremedium pass: 7
# spheresmall inspect: 7
# spheresmall lift: 3
# spheresmall offhand: 1
# spheresmall pass: 6
# stamp lift: 7
# stamp offhand: 1
# stamp pass: 4
# stamp stamp: 9
# stanfordbunny inspect: 7
# stanfordbunny lift: 7
# stanfordbunny offhand: 1
# stanfordbunny pass: 9
# stapler lift: 5
# stapler offhand: 1
# stapler offhand Retake: 1
# stapler pass: 8
# stapler staple: 14
# teapot lift: 2
# teapot pass: 8
# teapot pour: 8
# toothbrush brush: 3
# toothbrush lift: 2
# toothbrush pass: 5
# toothpaste lift: 4
# toothpaste pass: 6
# toothpaste squeeze: 7
# toothpaste squeeze Retake: 1
# toruslarge inspect: 5
# toruslarge inspect Retake: 1
# toruslarge lift: 5
# toruslarge pass: 8
# torusmedium inspect: 6
# torusmedium lift: 3
# torusmedium offhand: 1
# torusmedium pass: 6
# torussmall inspect: 5
# torussmall lift: 4
# torussmall offhand: 1
# torussmall pass: 7
# train lift: 6
# train pass: 8
# train play: 5
# watch lift: 3
# watch offhand: 1
# watch pass: 7
# watch set: 9
# waterbottle drink: 7
# waterbottle lift: 4
# waterbottle open: 4
# waterbottle open Retake: 1
# waterbottle pass: 7
# waterbottle pour: 5
# waterbottle shake: 5
# wineglass drink: 14
# wineglass lift: 5
# wineglass offhand: 1
# wineglass pass: 9
# wineglass toast: 7

# %%
for object_ in sorted(obj_count.keys()):
    print(f"{code_to_label[object_]}: {obj_count[object_]}")
# Out:
# airplane: 21
# alarmclock: 22
# apple: 26
# banana: 26
# binoculars: 17
# bowl: 26
# camera: 37
# cubesmall: 67
# cup: 33
# cylinderlarge: 66
# doorknob: 16
# duck: 18
# elephant: 21
# eyeglasses: 22
# flashlight: 20
# flute: 20
# fryingpan: 17
# gamecontroller: 20
# hammer: 28
# hand: 21
# headphones: 18
# knife: 10
# lightbulb: 6
# mouse: 22
# mug: 33
# phone: 20
# piggybank: 24
# pyramidlarge: 46
# scissors: 9
# spheremedium: 56
# stanfordbunny: 74
# teapot: 18
# toothpaste: 28
# toruslarge: 52
# train: 19
# waterbottle: 53
# wineglass: 36

# %%
# show all as histogram
import matplotlib.pyplot as plt

plt.bar(range(len(emotions_count)), list(emotions_count.values()), align='center')
plt.xticks(range(len(emotions_count)), list(emotions_count.keys()))
# add title: GRAB training set emotion distribution
plt.title("GRAB training emotion distribution")
plt.show()

# %%
# grab training object distribution
plt.bar(range(len(obj_count)), list(obj_count.values()), align='center')
plt.xticks(range(len(obj_count)), list(obj_count.keys()))
plt.xticks(rotation=90)
# add title: GRAB training set object distribution
plt.title("GRAB training object distribution")
# Out:
# Text(0.5, 1.0, 'GRAB training object distribution')

# %%
for obj in obj_count.keys():
    print(f"{obj} -> {code_to_label[obj]}")
# Out:
# mug -> mug
# air -> airplane
# lig -> lightbulb
# cam -> camera
# win -> wineglass
# pho -> phone
# bin -> binoculars
# tea -> teapot
# cub -> cubesmall
# ele -> elephant
# gam -> gamecontroller
# duc -> duck
# sta -> stanfordbunny
# tra -> train
# cyl -> cylinderlarge
# wat -> waterbottle
# sci -> scissors
# cup -> cup
# han -> hand
# doo -> doorknob
# sph -> spheremedium
# ala -> alarmclock
# mou -> mouse
# app -> apple
# kni -> knife
# flu -> flute
# fry -> fryingpan
# tor -> toruslarge
# hea -> headphones
# pyr -> pyramidlarge
# too -> toothpaste
# fla -> flashlight
# ban -> banana
# bow -> bowl
# pig -> piggybank
# ham -> hammer
# eye -> eyeglasses

# %%
seq_type = "airplane pass"
seq_emo_codes = [label_code(emo) for emo in seq_type_to_emotions[seq_type]]
print(f"emotions for {seq_type}: {seq_emo_codes}")
print(f"all emotions: {emotions_count.keys()}")
print(f"missing emotions: {set(emotions_count.keys()) - set(seq_emo_codes)}")
# Out:
# emotions for airplane pass: ['fea', 'dis', 'sad', 'hap', 'ang']
# all emotions: dict_keys(['con', 'hap', 'bot', 'neu', 'int', 'ang', 'bor', 'dis', 'uns', 'fea', 'sad', 'thi', 'sur'])
# missing emotions: {'int', 'sur', 'bot', 'thi', 'bor', 'con', 'neu', 'uns'}

# %%
emo = "surprise"
emo_code = label_code(emo)
names = emotion_to_name[emo_code]
print(f"seqs for emotion {code_to_label[emo_code]}")
for name in names:
    print(name)
# Out:
# seqs for emotion surprise
# s2/cubesmall_lift
# s2/stanfordbunny_lift
# s1/flashlight_pass_1
# s2/cubemedium_lift
# s2/elephant_pass_1
# s8/watch_lift
# s1/stamp_pass_1
# s7/cubesmall_pass_1
# s9/apple_pass_1
# s1/elephant_inspect_1
# s7/hand_pass_1
# s2/cylindermedium_lift
# s1/hammer_pass_1
# s6/phone_call_1
# s4/bowl_pass_1
# s1/phone_offhand_1
# s5/gamecontroller_play_1
# s5/apple_pass_1
# s6/hammer_use_1
# s9/toothbrush_pass_1
# s8/hand_inspect_1
# s1/headphones_pass_1
# s9/spheresmall_inspect_1
# s10/bowl_pass_1
# s9/airplane_lift
# s8/mug_offhand_1

# %%
arrays = names_to_arrays(data_dir, names)
# Out:
# shape of s2/cubesmall_lift: (572, 212)
# shape of s2/stanfordbunny_lift: (757, 212)
# shape of s1/flashlight_pass_1: (251, 212)
# shape of s2/cubemedium_lift: (486, 212)
# shape of s2/elephant_pass_1: (248, 212)
# shape of s8/watch_lift: (610, 212)
# shape of s1/stamp_pass_1: (292, 212)
# shape of s7/cubesmall_pass_1: (188, 212)
# shape of s9/apple_pass_1: (159, 212)
# shape of s1/elephant_inspect_1: (308, 212)
# shape of s7/hand_pass_1: (195, 212)
# shape of s2/cylindermedium_lift: (853, 212)
# shape of s1/hammer_pass_1: (248, 212)
# shape of s6/phone_call_1: (456, 212)
# shape of s4/bowl_pass_1: (199, 212)
# shape of s1/phone_offhand_1: (328, 212)
# shape of s5/gamecontroller_play_1: (247, 212)
# shape of s5/apple_pass_1: (176, 212)
# shape of s6/hammer_use_1: (252, 212)
# shape of s9/toothbrush_pass_1: (204, 212)
# shape of s8/hand_inspect_1: (291, 212)
# shape of s1/headphones_pass_1: (243, 212)
# shape of s9/spheresmall_inspect_1: (170, 212)
# shape of s10/bowl_pass_1: (178, 212)
# shape of s9/airplane_lift: (488, 212)
# shape of s8/mug_offhand_1: (272, 212)

# %%
print(f"calc stats for {len(arrays)} arrays")
mean, std = calc_mean_stddev_pose(arrays)
# add 1 dimension to mean and std
mean = mean.reshape(1, -1)
std = std.reshape(1, -1)
# Out:
# calc stats for 26 arrays

# %%
print(f"mean shape {mean.shape}")
print(f"std shape {std.shape}")
# Out:
# mean shape (1, 212)
# std shape (1, 212)

# %%
mean_dict = motion_arr_to_dict(mean, shapes_dropped=True)
std_dict = motion_arr_to_dict(std, shapes_dropped=True)
print(f"surprise mean: {mean_dict['face_expr']}")
print(f"surprise std: {std_dict['face_expr']}")
# Out:
# surprise mean: tensor([[ 0.3944,  1.0355, -0.1104,  0.3438,  0.1835,  0.3515, -0.4112,  0.8183,
#          -0.3203, -0.0656, -0.2213, -0.1106, -0.5442,  0.4136,  0.1552,  0.0691,
#          -0.2591,  0.1572, -0.1857,  0.2525,  0.1290,  0.2594, -0.3789,  0.0457,
#          -0.0049, -0.1438, -0.0413, -0.1620, -0.3905, -0.2516, -0.0828,  0.0523,
#           0.4467, -0.4080,  0.1744, -0.1148, -0.2176,  0.0395,  0.1339,  0.3428,
#           0.2916, -0.1423, -0.0314, -0.0233, -0.0612,  0.0477,  0.0232,  0.2205,
#          -0.0019,  0.1335]])
# surprise std: tensor([[0.7210, 0.7371, 0.3311, 0.4672, 0.9656, 0.7212, 0.9995, 0.8425, 0.6267,
#          1.1531, 0.5747, 0.8608, 0.5243, 0.2150, 0.6206, 0.2514, 0.6583, 0.3428,
#          0.5910, 0.1835, 0.2937, 0.5265, 0.7656, 0.4151, 0.3056, 0.2745, 0.1566,
#          0.5495, 0.4626, 0.4047, 0.1767, 0.2355, 0.5954, 0.6374, 0.3063, 0.2315,
#          0.3174, 0.1950, 0.2760, 0.6069, 0.4781, 0.3419, 0.1015, 0.1178, 0.1603,
#          0.2853, 0.1881, 0.2943, 0.1791, 0.2315]])

# %%
# load std.npy from data dir
std_train = np.load(pjoin(data_dir, "Std.npy"))
std_train = std_train.reshape(1, -1)
mean_train = np.load(pjoin(data_dir, "Mean.npy"))
mean_train = mean_train.reshape(1, -1)
mean_train_dict = motion_arr_to_dict(mean_train, shapes_dropped=True)
std_train_dict = motion_arr_to_dict(std_train, shapes_dropped=True)
print(f"mean: {mean_train_dict['face_expr']}")
print(f"std: {std_train_dict['face_expr']}")
# Out:
# mean: tensor([[ 0.9793,  1.1955, -0.1761,  0.2503, -0.0148, -0.1734, -0.0857,  0.2882,
#          -0.1658, -0.1143, -0.1749,  0.0256, -0.3031,  0.3240,  0.1928, -0.0123,
#          -0.4032,  0.0880, -0.1201,  0.2633,  0.1121,  0.1342, -0.0902,  0.0071,
#          -0.0969, -0.0379, -0.0360,  0.0097, -0.2914, -0.2203, -0.0764, -0.0385,
#           0.3104, -0.2582,  0.1217, -0.1046, -0.0752,  0.0608,  0.0820,  0.2003,
#           0.2053, -0.0535, -0.0106,  0.0088, -0.0766, -0.0099,  0.0547,  0.0924,
#           0.0387,  0.1299]])
# std: tensor([[1.0655, 1.0759, 0.4935, 0.4183, 0.7407, 0.6360, 0.9216, 0.6985, 0.6380,
#          0.9843, 0.5477, 0.6577, 0.4538, 0.2694, 0.5082, 0.2214, 0.4444, 0.2400,
#          0.4524, 0.1704, 0.2673, 0.3875, 0.5558, 0.3554, 0.2595, 0.2144, 0.1623,
#          0.4468, 0.3424, 0.2883, 0.1587, 0.1878, 0.4116, 0.4483, 0.1814, 0.1800,
#          0.2852, 0.1462, 0.2142, 0.4437, 0.3668, 0.2245, 0.1168, 0.1120, 0.1565,
#          0.2382, 0.1440, 0.2470, 0.1249, 0.1625]])
